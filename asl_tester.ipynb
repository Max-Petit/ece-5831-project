# %% [markdown]
# # ASL Interpreter Testing

# %% [markdown]
# ## Run asl script

# %%
run asl.py

# %% [markdown]
# ## Create asl object

# %%
asl = Asl()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_3 (Conv2D)           (None, 28, 28, 32)        320
#
#  max_pooling2d_3 (MaxPooling  (None, 14, 14, 32)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 14, 14, 64)        18496
#
#  max_pooling2d_4 (MaxPooling  (None, 7, 7, 64)         0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 7, 7, 128)         73856
#
#  max_pooling2d_5 (MaxPooling  (None, 3, 3, 128)        0
#  2D)
#
#  flatten_1 (Flatten)         (None, 1152)              0
#
#  dense_2 (Dense)             (None, 512)               590336
#
#  dense_3 (Dense)             (None, 24)                12312
#
# ...
# Total params: 695,320
# Trainable params: 695,320
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Train asl model passing number of epochs

# %%
asl.train_model(1)
# Out:
# 858/858 [==============================] - 15s 17ms/step - loss: 0.1300 - accuracy: 0.3544 - val_loss: 0.0481 - val_accuracy: 0.7865

# %% [markdown]
# ## Plot model training vs epochs

# %%
asl.plot_history()

# %% [markdown]
# ## Print out loss asn accuracy of trained model

# %%
asl.evaluate()
# Out:
# 225/225 [==============================] - 1s 4ms/step - loss: 0.0481 - accuracy: 0.7865
# [INFO] Test loss: 0.04811186343431473
# [INFO] Test accuracy: 0.7865309715270996

# %% [markdown]
# ## Test trained model using prediciton

# %%
asl.predict(112)
# Out:
# 1/1 [==============================] - 0s 20ms/step
# prediction:
# a

# %% [markdown]
# ## Load lookup table of ASL to check prediction against

# %%
asl.show_asl_chart()

# %% [markdown]
# ## Comparing the prediciton print out and image vs the look up tabel we can see the prediciton was accurate

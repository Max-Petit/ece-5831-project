# %%
import asl

# %%
asl = Asl()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_13 (Conv2D)          (None, 28, 28, 32)        320
#
#  max_pooling2d_12 (MaxPoolin  (None, 14, 14, 32)       0
#  g2D)
#
#  conv2d_14 (Conv2D)          (None, 14, 14, 64)        18496
#
#  max_pooling2d_13 (MaxPoolin  (None, 7, 7, 64)         0
#  g2D)
#
#  conv2d_15 (Conv2D)          (None, 7, 7, 128)         73856
#
#  max_pooling2d_14 (MaxPoolin  (None, 3, 3, 128)        0
#  g2D)
#
#  flatten_4 (Flatten)         (None, 1152)              0
#
#  dense_8 (Dense)             (None, 512)               590336
#
#  dense_9 (Dense)             (None, 24)                12312
#
# ...
# Total params: 695,320
# Trainable params: 695,320
# Non-trainable params: 0
# _________________________________________________________________

# %%
asl.get_data()

# %%
asl.train_model(2)
# Out:
# Epoch 1/2
# 858/858 [==============================] - 16s 18ms/step - loss: 0.1263 - accuracy: 0.3727 - val_loss: 0.0459 - val_accuracy: 0.8087
# Epoch 2/2
# 858/858 [==============================] - 15s 17ms/step - loss: 0.0126 - accuracy: 0.9667 - val_loss: 0.0178 - val_accuracy: 0.9511

# %%
asl.plot_history()

# %%
asl.evaluate()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 asl.evaluate()
#
# AttributeError: module 'asl' has no attribute 'evaluate'
